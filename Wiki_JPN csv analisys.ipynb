# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


df = pd.read_csv('wikiJPN_data.csv')

# %%
#欠損値の除外
df2 = df.dropna(how='any')
df2
# Out:
#     Rank  Fortune 500rank                             Name  \
# 0      1               10                           Toyota
# 1      2               41                       Mitsubishi
# 2      3               61                            Honda
# 3      4               78                           Itochu
# 4      5               83   Nippon Telegraph and Telephone
# 5      6               88                           Mitsui
# 6      7               94              Japan Post Holdings
# 7      8              113                          Hitachi
# 8      9              116                             Sony
# 9     10              140                   ENEOS Holdings
# 10    11              147           Seven & I Holdings Co.
# 11    12              148                             AEON
# 12    13              157                         Marubeni
# 13    14              161                           Nissan
# 14    15              164                      Nippon Life
# 15    16              167                    Dai-ichi Life
# 16    17              172                    Toyota Tsusho
# 17    18              193                        Panasonic
# 18    19              214                     Nippon Steel
# 19    20              234                   SoftBank Group
# 20    21              240   Mitsubishi UFJ Financial Group
# 21    22              250                   Idemitsu Kosan
# 22    23              253                     Tokio Marine
# 23    24              278                            Denso
# 24    25              279                   Sumitomo Group
# 25    26              290     Tokyo Electric Power Company
# 26    26              309            MS&AD Insurance Group
# 27    27              351              Mitsubishi Electric
# 28    28              354                      Daiwa House
# 29    29              358                     JFE Holdings
# 30    30              377                Meiji Yasuda Life
# 31    31              383                   Sompo Holdings
# 32    32              388  Sumitomo Mitsui Financial Group
# 33    33              401     Mitsubishi Chemical Holdings
# 34    34              404           Mizuho Financial Group
# 36    36              418      Mitsubishi Heavy Industries
# 37    37              442          Sumitomo Life Insurance
# 38    38              444                       Canon Inc.
# 39    39              446                          Fujitsu
# 40    40              448            Takeda Pharmaceutical
# 41    41              449                     Suzuki Motor
# 43    43              480                          Toshiba
# 44    44              484                      Bridgestone
# 45    45              489                 Medipal Holdings
#
#               Industry  Revenue  Profits     Assets Employees Headquarters
# 0           Automotive  279,377   25,371    557,522   372,817       Toyota
# 1         Conglomerate  153,690    8,345    180,479    80,728        Tokyo
# 2           Automotive  129,546    6,294    197,456   204,035        Tokyo
# 3              Trading  109,215    7,302    100,104   136,722        Tokyo
# 4   Telecommunications  108,215   10,513    196,542   333,840        Tokyo
# 5         Conglomerate  104,664    8,142    122,916    44,336        Tokyo
# 6         Conglomerate  100,278    4,466  2,502,652   232,112        Tokyo
# 7         Conglomerate   91,374    5,194    114,385   368,247        Tokyo
# 8         Conglomerate   88,320    4,781     79,468    41,852        Tokyo
# 9          Oil and Gas   80,132    4,781     79,468    41,852        Tokyo
# 10              Retail   78,458    1,890     75,888   127,196        Tokyo
# 11              Retail   78,155     58.3    101,016   288,064        Chiba
# 12             Trading   75,742    3,777     67,997    49,623        Tokyo
# 13          Automotive   74,994    1,918    134,844   141,983     Yokohama
# 14           Insurance   74,392    3,086    727,962    92,737        Osaka
# 15           Insurance   73,082    3,644    542,633    62,294        Tokyo
# 16             Trading   71,464    1,978     50,598    65,218       Nagoya
# 17         Electronics   65,774    2,273     66,086   240,198        Osaka
# 18               Steel   60,612    5,673     72,089   115,667        Tokyo
# 19        Conglomerate   55,383  -15,204    391,604    59,721        Tokyo
# 20          Financials   54,087   10,066  3,078,263   135,042        Tokyo
# 21         Oil and Gas   52,335    2,488     37,897    16,606        Tokyo
# 22           Insurance   52,198    3,743    224,411    43,048        Tokyo
# 23          Automotive   49,098    2,349     61,216   167,950       Kariya
# 24             Trading   48,916    4,127     78,924    74,253        Tokyo
# 25    Electric utility   47,268     50.2    105,868    37,939        Tokyo
# 26           Insurance   45,685    2,339    206,192    39,962        Tokyo
# 27         Electronics   39,851    1,811     42,072   145,696        Tokyo
# 28        Construction   39,520    2,005     45,072    48,831        Osaka
# 29               Steel   38,858    2,564     43,554    64,296        Tokyo
# 30           Insurance   37,515    1,618    397,022    48,179        Tokyo
# 31           Insurance   37,098    2,001    113,564    47,776        Tokyo
# 32             Banking   36,596    6,290      2,122   101,023        Tokyo
# 33           Chemicals   35,402    1,577     45,909    69,784        Tokyo
# 34             Banking   35,279    4,722  1,952,608    52,464        Tokyo
# 36         Industrials   34,363    1,010     42,141    77,991        Tokyo
# 37           Insurance   32,041      406    354,124    42,954        Osaka
# 38         Electronics   32,005    1,956     41,265   184,034        Tokyo
# 39  Telecommunications   31,929    1,626     27,442   124,216        Tokyo
# 40     Pharmaceuticals   31,771    2,048    108,541    47,347        Tokyo
# 41          Automotive   31,765    1,427     34,224    69,193    Hamamatsu
# 43         Electronics   29,705    1,732     30,759   116,224        Tokyo
# 44          Automotive   29,570    3,589     39,736   135,636        Tokyo
# 45              Retail   29,295    261.9     14,080    14,454        Tokyo

# %%
#東京本社の数
number_TOKYO = (df2['Headquarters']== 'Tokyo').sum()
print('num_data='+str(number_TOKYO))
# Out:
# num_data=34

# %%
df2.plot(kind='scatter',x = 'Revenue', y = 'Profits')
plt.xlabel('Revenue')
plt.ylabel('Profits')
plt.show()

# %%
#散布図
#df2.plot.scatter(x='Revenue',y='Employees',s=100, c='lime', marker='v')

# %%
#折れ線と棒グラフ
plt.plot(df2.Revenue, df2.Profits,'o')
plt.show()

# %%
#df2.plot.scatter(x='Profits',y='Employees',s=50, c='Red', marker='D')

# %%
#RとPの列だけ抽出
df_RP = df.loc[:,['Revenue','Profits']]
df_RP
# Out:
#     Revenue  Profits
# 0   279,377   25,371
# 1   153,690    8,345
# 2   129,546    6,294
# 3   109,215    7,302
# 4   108,215   10,513
# 5   104,664    8,142
# 6   100,278    4,466
# 7    91,374    5,194
# 8    88,320    4,781
# 9    80,132    4,781
# 10   78,458    1,890
# 11   78,155     58.3
# 12   75,742    3,777
# 13   74,994    1,918
# 14   74,392    3,086
# 15   73,082    3,644
# 16   71,464    1,978
# 17   65,774    2,273
# 18   60,612    5,673
# 19   55,383  ∁E5,204
# 20   54,087   10,066
# 21   52,335    2,488
# 22   52,198    3,743
# 23   49,098    2,349
# 24   48,916    4,127
# 25   47,268     50.2
# 26   45,685    2,339
# 27   39,851    1,811
# 28   39,520    2,005
# 29   38,858    2,564
# 30   37,515    1,618
# 31   37,098    2,001
# 32   36,596    6,290
# 33   35,402    1,577
# 34   35,279    4,722
# 35   34,872      221
# 36   34,363    1,010
# 37   32,041      406
# 38   32,005    1,956
# 39   31,929    1,626
# 40   31,771    2,048
# 41   31,765    1,427
# 42   28,578      669
# 43   29,705    1,732
# 44   29,570    3,589
# 45   29,295    261.9

# %%
#Bar chart
x = df['Revenue']
y = df['Profits']

plt.xlabel('Revenue')
plt.ylabel('Profits')
plt.bar(x,y)
# Out:
# <BarContainer object of 46 artists>

# %%
df2.describe()
# Out:
#             Rank  Fortune 500rank
# count  44.000000        44.000000
# mean   22.363636       263.545455
# std    12.828186       142.417411
# min     1.000000        10.000000
# 25%    11.750000       147.750000
# 50%    22.500000       251.500000
# 75%    32.250000       391.250000
# max    45.000000       489.000000

# %%
# Bar chart
plt.xlabel('Heardquarters', fontsize=18)
plt.ylabel('Employees', fontsize=16)
plt.bar(x, y)
# Out:
# <BarContainer object of 46 artists>
